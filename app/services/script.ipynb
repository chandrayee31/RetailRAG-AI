# %%
from loader_service import load_documents
doc=load_documents("../../data/docs")
print(len(doc))
print(doc[0].page_content)
# Out:
# 3
# Customers can contact support via email or chat.
# Support is available Monday to Friday, 9 AM to 6 PM.

# %%
import os

print("cwd:", os.getcwd())
print("exists:", os.path.exists("../../data/docs"))
print("files:", os.listdir("../../data/docs") if os.path.exists("../../data/docs") else "folder not found")
# Out:
# cwd: /Users/chandrayeekumar/Documents/retailrag-ai/app/services
# exists: True
# files: ['support_faq.txt', 'shipping_policy.txt', 'refund_policy.txt']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       5 docs = load_documents()
#       6 chunks = split_documents(docs)
# ----> 7 vectorstore = create_vectorstore(chunks)
#       9 print("Vectorstore created successfully")
#
# File ~/Documents/retailrag-ai/app/services/embedding_service.py:8, in create_vectorstore(chunks, persist_directory)
#       5 def create_vectorstore(chunks, persist_directory="vectorstore"):
#       6     embeddings = OllamaEmbeddings(model="nomic-embed-text")
# ----> 8     vectorstore = Chroma.from_documents(
#       9         documents=chunks,
#      10         embedding=embeddings,
#      11         persist_directory=persist_directory
#      12     )
#      14     return vectorstore
#
# ...

# %%
from loader_service import load_documents
from chunk_service import split_documents

docs = load_documents("../../data/docs")
print("docs:", len(docs))

if docs:
    print("first doc preview:", docs[0].page_content[:200])

chunks = split_documents(docs)
print("chunks:", len(chunks))

if chunks:
    print("first chunk preview:", chunks[0].page_content[:200])
# Out:
# docs: 3
# first doc preview: Customers can contact support via email or chat.
# Support is available Monday to Friday, 9 AM to 6 PM.
# chunks: 3
# first chunk preview: Customers can contact support via email or chat.
# Support is available Monday to Friday, 9 AM to 6 PM.

# %%
if not chunks:
    print("No chunks created. Check document loading and splitting.")
else:
    vectorstore = create_vectorstore(chunks)
    print("Vectorstore created successfully")
# Out:
# Vectorstore created successfully

# %%
from loader_service import load_documents
from chunk_service import split_documents
from embedding_service import create_vectorstore

docs = load_documents("../../data/docs")
chunks = split_documents(docs)
vectorstore = create_vectorstore(chunks)

print("Vectorstore created successfully")
# Out:
# Vectorstore created successfully

# %%
from retrieval_service import get_retriever

retriever = get_retriever()
results = retriever.get_relevant_documents("What is the refund policy?")

print(len(results))
print(results[0].page_content)
# Out:
# 3
# Customers may return products within 30 days of purchase.
# Items must be unused and in original packaging.
# Refunds are processed within 5 business days.
# /Users/chandrayeekumar/Documents/retailrag-ai/app/services/retrieval_service.py:8: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(
# /var/folders/wd/5nhmrhq92s9g16dvwgnss_j00000gn/T/ipykernel_90502/1632555107.py:4: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   results = retriever.get_relevant_documents("What is the refund policy?")

# %%
from retrieval_service import get_retriever
from prompt_service import build_rag_prompt

retriever = get_retriever()
docs = retriever.get_relevant_documents("What is the refund policy?")
prompt = build_rag_prompt("What is the refund policy?", docs)

print(prompt)
# Out:
# You are a helpful knowledge assistant.
#
# Answer the user's question only using the provided context.
# If the answer is not in the context, say:
# "I could not find that information in the provided documents."
#
# Context:
# Customers may return products within 30 days of purchase.
# Items must be unused and in original packaging.
# Refunds are processed within 5 business days.
#
# Customers may return products within 30 days of purchase.
# Items must be unused and in original packaging.
# Refunds are processed within 5 business days.
#
# Customers can contact support via email or chat.
# Support is available Monday to Friday, 9 AM to 6 PM.
#
# Question:
# What is the refund policy?
#
# Provide:
# 1. A clear answer
# 2. A short supporting explanation
# 3. Mention that the answer is based on the uploaded documents

# %%
from retrieval_service import get_retriever
from prompt_service import build_rag_prompt
from llm_service import generate_rag_answer

question = "What is the refund policy?"
retriever = get_retriever()
docs = retriever.get_relevant_documents(question)
prompt = build_rag_prompt(question, docs)

answer = generate_rag_answer(prompt)
print(answer)
# Out:
# Answer:
# Refunds are processed within 5 business days. Items must be unused and in original packaging, and returns must be made within 30 days of purchase.
#
# Supporting Explanation:
# According to the provided documents, the refund policy requires that items be returned unused and in their original packaging within 30 days of purchase. Refunds are then processed within 5 business days.
#
# Answer Based On:
# This answer is based on the uploaded documents provided, which outline the return and refund policy for customers.
